# %%
import pandas as pd

# %%
train=pd.read_csv("train2.csv")
test=pd.read_csv("test2.csv")

# %%
# now concatenate both train & test
df=pd.concat([train,test],axis=0)

# %%
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1454         160       RM         21.0     1936   Pave      Reg         Lvl
# 1455         160       RM         21.0     1894   Pave      Reg         Lvl
# 1456          20       RL        160.0    20000   Pave      Reg         Lvl
# 1457          85       RL         62.0    10441   Pave      Reg         Lvl
# 1458          60       RL         74.0     9627   Pave      Reg         Lvl
#
# ...

# %% [raw]
# as we can see there are Nan values in salePrice at  the tail of df bcz test data don't has SalePrice

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1454         160         21.0     1936            4            7       1970
# 1455         160         21.0     1894            4            5       1970
# 1456          20        160.0    20000            5            7       1960
# 1457          85         62.0    10441            5            5       1992
# 1458          60         74.0     9627            7            5       1993
#
# ...

# %%
df=df.loc[:,~df.columns.duplicated()]

# %%
df.shape
# Out:
# (2919, 237)

# %%
#now saprate train and test data

# %%
train.shape,test.shape
# Out:
# ((1460, 76), (1459, 75))

# %%
df_train=df.iloc[:1460,:]
df_test=df.iloc[1460:,:]

# %%
df_train.shape,df_test.shape
# Out:
# ((1460, 237), (1459, 236))

# %%
df_test.drop(['SalePrice'],axis=1,inplace=True)
# Out:
# C:\Users\rhpy7\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_test.to_csv('test3.csv',index=False)

# %%
x_train=df_train.drop(['SalePrice'],axis=1)
y_train=df_train['SalePrice']

# %%
x_train.shape,y_train.shape
# Out:
# ((1460, 236), (1460,))

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
import joblib

# %%
joblib.dump(rf,'model')
# Out:
# ['model']

# %%
import numpy as np

# %%
df_test=np.float32(df_test)

# %%
rf.predict(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-2782b403adc8> in <module>
# ----> 1 rf.predict(df_test)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     782         check_is_fitted(self)
#     783         # Check data
# --> 784         X = self._validate_X_predict(X)
#     785
#     786         # Assign chunk of trees to jobs
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py in _validate_X_predict(self, X)
#     420         check_is_fitted(self)
#     421
# --> 422         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     423
#     424     @property
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
# ...

# %%
x=[feature for feature in df_test.columns if df_test[feature].isnull().sum()>1]

# %%
# Out:
# []
